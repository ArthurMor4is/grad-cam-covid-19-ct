# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
from tensorflow.keras import layers
import matplotlib.cm as cm
import random
import glob
import os
from skimage.segmentation import chan_vese
import numpy as np
import PIL 
from PIL import Image 
from tensorboard.plugins.hparams import api as hp
import pandas as pd
from shutil import copy
import cv2

# Display
# from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# My functions
import my_functions as mf

# tf explain
from tf_explain.callbacks.grad_cam import GradCAMCallback

# %%
import my_functions as mf

# %%
random_seed = 42

# %%
batch_size = 32
img_height = 180
img_width = 180
image_size = (img_height, img_width)

# %%
src_folder_path = "datasets\\ct_scan_3\\train\\COVID-negative\\"
des_folder_path = "datasets\\ct_scan_7\\train_contrast\\COVID-negative\\"
mf.aply_black_tophat_to_folder(src_folder_path, des_folder_path, disk_size=12)
# Out:
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0001_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0002_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0004_33.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0005_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_10.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_11.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0006_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0007_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_10.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_11.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0008_9.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_10.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_11.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0009_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_33.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_34.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0010_35.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0011_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0012_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_11.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0013_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0014_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0016_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0017_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0018_33.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0020_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0021_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0023_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0024_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0025_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0026_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_10.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_11.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0027_9.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_10.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_11.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0028_9.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_10.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_11.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0029_9.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0030_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_10.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_11.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_12.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_8.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0031_9.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_23.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_24.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_25.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_26.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_27.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_28.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_29.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_30.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_31.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0032_32.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_13.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_14.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_15.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_16.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_17.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_18.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_19.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_20.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_21.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_22.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\16_Morozov_study_0033_23.png
# ...
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_102.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_104.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_106.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_109.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_111.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_113.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_115.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_117.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal014_120.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_75.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_77.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_79.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_82.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_84.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_86.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_88.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_90.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_93.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal016_95.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_158.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_160.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_162.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_164.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_166.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_169.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_171.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_173.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_175.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal017_177.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_100.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_102.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_105.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_107.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_109.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_111.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_113.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_94.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_96.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal018_98.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_100.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_103.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_105.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_107.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_109.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_89.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_92.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_94.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_96.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal019_98.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_100.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_102.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_104.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_107.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_109.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_111.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_113.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_115.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_96.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal020_98.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_124.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_126.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_128.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_130.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_132.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_135.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_137.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_139.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_141.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal021_143.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_114.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_116.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_119.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_121.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_123.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_125.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_127.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_130.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_132.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal022_134.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_134.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_136.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_138.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_140.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_143.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_145.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_147.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_149.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_151.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal023_154.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_142.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_144.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_147.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_149.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_151.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_153.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_155.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_158.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_160.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal024_162.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_125.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_127.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_129.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_131.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_133.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_136.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_138.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_140.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_142.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal025_144.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_111.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_113.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_116.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_118.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_120.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_122.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_124.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_127.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_129.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal026_131.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_143.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_145.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_148.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_150.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_152.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_154.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_156.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_159.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_161.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal027_163.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_106.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_108.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_110.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_113.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_115.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_117.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_119.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_121.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_124.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal028_126.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_100.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_102.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_104.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_107.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_109.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_111.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_113.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_115.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_96.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal029_98.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_100.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_102.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_104.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_84.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_86.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_89.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_91.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_93.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_95.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal030_97.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_140.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_142.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_144.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_147.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_149.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_151.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_153.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_155.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_158.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal031_160.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_109.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_111.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_113.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_116.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_118.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_120.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_122.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_124.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_127.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal032_129.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_78.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_80.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_82.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_85.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_87.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_89.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_91.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_93.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_96.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal035_98.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_130.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_132.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_134.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_136.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_139.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_141.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_143.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_145.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_147.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal036_150.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_112.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_114.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_117.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_119.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_121.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_123.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_125.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_128.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_130.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal037_132.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_170.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_172.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_174.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_177.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_179.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_181.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_183.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_185.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_4.png
# Current_image: datasets\ct_scan_3\train\COVID-negative\normal038_6.png
