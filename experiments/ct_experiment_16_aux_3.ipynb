# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
from tensorflow.keras import layers
import matplotlib.cm as cm
import random
import glob
import os
from skimage.segmentation import chan_vese
import numpy as np
import PIL 
from PIL import Image 
from tensorboard.plugins.hparams import api as hp
import pandas as pd
from shutil import copy
import cv2

# Display
# from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# My functions
import my_functions as mf

# tf explain
from tf_explain.callbacks.grad_cam import GradCAMCallback

# %%
import my_functions as mf

# %%
random_seed = 42

# %%
batch_size = 32
img_height = 180
img_width = 180
image_size = (img_height, img_width)

# %%
src_folder_path = "datasets\\ct_scan_3\\val\\COVID-negative\\"
des_folder_path = "datasets\\ct_scan_7\\val_contrast\\COVID-negative\\"
mf.aply_black_tophat_to_folder(src_folder_path, des_folder_path, disk_size=12)
# Out:
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_11.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_12.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_13.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_14.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_15.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_16.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_17.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_18.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_19.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_20.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_21.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_22.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_23.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_24.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_25.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_26.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_27.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_28.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_29.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0003_30.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_13.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_14.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_15.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_16.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_17.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_18.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_19.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_20.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_21.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_22.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_23.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_24.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_25.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_26.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_27.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_28.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_29.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_30.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_31.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0015_32.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_13.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_14.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_15.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_16.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_17.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_18.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_19.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_20.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_21.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_22.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_23.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_24.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_25.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_26.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_27.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_28.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_29.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_30.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_31.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0019_32.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_13.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_14.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_15.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_16.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_17.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_18.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_19.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_20.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_21.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_22.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_23.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_24.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_25.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_26.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_27.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_28.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_29.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_30.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_31.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0022_32.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_14.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_15.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_16.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_17.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_18.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_19.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_20.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_21.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_22.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_23.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_24.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_25.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_26.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_27.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_28.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_29.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_30.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_31.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_32.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0035_33.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_17.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_18.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_19.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_20.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_21.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_22.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_23.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_24.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_25.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_26.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_27.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_28.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_29.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_30.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_31.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_32.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_33.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_34.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_35.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0040_36.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_10.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_11.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_12.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_13.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_14.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_15.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_16.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_17.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_18.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_19.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_20.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_21.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_22.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_23.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_24.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_25.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_26.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_7.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_8.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0042_9.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_11.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_12.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_13.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_14.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_15.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_16.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_17.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_18.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_19.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_20.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_21.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_22.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_23.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_24.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_25.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_26.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_27.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_28.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_29.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0054_30.png
# Current_image: datasets\ct_scan_3\val\COVID-negative\16_Morozov_study_0057_10.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f00d2f6cd2b9> in <module>
#       1 src_folder_path = "datasets\\ct_scan_3\\val\\COVID-negative\\"
#       2 des_folder_path = "datasets\\ct_scan_7\\val_contrast\\COVID-negative\\"
# ----> 3 mf.aply_black_tophat_to_folder(src_folder_path, des_folder_path, disk_size=12)
#
# c:\Users\arthur.morais\Desktop\code_projects\grad_cam_code\my_functions.py in aply_black_tophat_to_folder(original_folder_path, destination_folder_path, disk_size)
#     263       image_name = current_image_path.split('\\')[-1]
#     264       print("Current_image: {}".format(current_image_path))
# --> 265       result_image = aply_black_tophat_to_image(original_image_path=current_image_path, disk_size=disk_size)
#     266       tf.keras.utils.save_img(
#     267          path="{}seg_version_{}".format(destination_folder_path, image_name),
#
# c:\Users\arthur.morais\Desktop\code_projects\grad_cam_code\my_functions.py in aply_black_tophat_to_image(original_image_path, disk_size)
#     254    normalize_slice = np.true_divide(sample_slice, [255.0], out=None)
#     255    footprint = disk(disk_size)
# --> 256    w_tophat = black_tophat(normalize_slice, footprint)
#     257    w_tophat = np.uint8(255 * w_tophat)
#     258    return w_tophat[:, :, np.newaxis]
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\misc.py in func_out(image, selem, *args, **kwargs)
#      37         if selem is None:
#      38             selem = _default_selem(image.ndim)
# ---> 39         return func(image, selem=selem, *args, **kwargs)
#      40
#      41     return func_out
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\grey.py in black_tophat(image, selem, out)
#     482     else:
#     483         original = image
# --> 484     out = closing(image, selem, out=out)
#     485     if np.issubdtype(out.dtype, np.bool_):
#     486         np.logical_xor(out, original, out=out)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\misc.py in func_out(image, selem, *args, **kwargs)
#      37         if selem is None:
#      38             selem = _default_selem(image.ndim)
# ---> 39         return func(image, selem=selem, *args, **kwargs)
#      40
#      41     return func_out
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\grey.py in func_out(image, selem, out, *args, **kwargs)
#     120         else:
#     121             out_temp = out
# --> 122         out_temp = func(image, selem, out=out_temp, *args, **kwargs)
#     123         if padding:
#     124             out[:] = crop(out_temp, pad_widths)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\grey.py in closing(image, selem, out)
#     347
#     348     """
# --> 349     dilated = dilation(image, selem)
#     350     # note: shift_x, shift_y do nothing if selem side length is odd
#     351     out = erosion(dilated, selem, out=out, shift_x=True, shift_y=True)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\misc.py in func_out(image, selem, *args, **kwargs)
#      37         if selem is None:
#      38             selem = _default_selem(image.ndim)
# ---> 39         return func(image, selem=selem, *args, **kwargs)
#      40
#      41     return func_out
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\grey.py in dilation(image, selem, out, shift_x, shift_y)
#     249     if out is None:
#     250         out = np.empty_like(image)
# --> 251     ndi.grey_dilation(image, footprint=selem, output=out)
#     252     return out
#     253
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\ndimage\morphology.py in grey_dilation(input, size, footprint, structure, output, mode, cval, origin)
#    1368
#    1369     return filters._min_or_max_filter(input, size, footprint, structure,
# -> 1370                                       output, mode, cval, origin, 0)
#    1371
#    1372
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\ndimage\filters.py in _min_or_max_filter(input, size, footprint, structure, output, mode, cval, origin, minimum)
#    1150         mode = _ni_support._extend_mode_to_code(mode)
#    1151         _nd_image.min_or_max_filter(input, footprint, structure, output,
# -> 1152                                     mode, cval, origins, minimum)
#    1153     if temp_needed:
#    1154         temp[...] = output
#
# KeyboardInterrupt:
