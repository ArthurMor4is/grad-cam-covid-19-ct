# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
from tensorflow.keras import layers
import matplotlib.cm as cm
import random
import glob
import os
from skimage.segmentation import chan_vese
import numpy as np
import PIL 
from PIL import Image 
from tensorboard.plugins.hparams import api as hp
import pandas as pd
from shutil import copy
import cv2

# Display
# from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# My functions
import my_functions as mf

# tf explain
from tf_explain.callbacks.grad_cam import GradCAMCallback

# %%
import my_functions as mf

# %%
random_seed = 42

# %%
batch_size = 32
img_height = 180
img_width = 180
image_size = (img_height, img_width)

# %%
src_folder_path = "datasets\\ct_scan_3\\val\\COVID-positive\\"
des_folder_path = "datasets\\ct_scan_7\\val_contrast\\COVID-positive\\"
mf.aply_black_tophat_to_folder(src_folder_path, des_folder_path, disk_size=12)
# Out:
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_100.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_25.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_29.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_33.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_35.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_37.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_4.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_40.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_61.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_67.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_76.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_77.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_78.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_80.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_87.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_89.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_91.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\13_Bjorke_95.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_10.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_11.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_19.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_23.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_24.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_25.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_26.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_27.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_28.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_29.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_30.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_5.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_6.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_7.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_8.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\14_Jun_radiopaedia_4_85506_1_case19_9.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\15_Cohen_1-s2.0-S0929664620300449-gr3_lrg-a.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\15_Cohen_1-s2.0-S0929664620300449-gr3_lrg-b.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\15_Cohen_1-s2.0-S0929664620300449-gr3_lrg-c.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\15_Cohen_1-s2.0-S0929664620300449-gr3_lrg-d.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\15_Cohen_16751_2_1.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\15_Cohen_16751_2_2.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_19.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_23.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_24.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_25.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_26.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_27.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_28.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_29.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_30.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0258_31.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0260_11.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0260_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0260_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0260_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0260_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0260_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0260_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0260_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_19.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_23.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_24.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_25.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_26.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_27.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_28.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_29.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_31.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0269_32.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_10.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_11.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_19.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_23.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_5.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_6.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_7.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_8.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0270_9.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_11.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_19.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_23.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_24.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_25.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_26.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_27.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_28.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_29.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_30.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_32.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_35.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_36.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_38.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_39.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0275_9.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_23.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_24.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_25.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_26.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_27.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_28.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_29.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0278_30.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0283_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0283_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0283_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0283_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0283_19.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0296_11.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0296_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0296_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0296_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0296_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0296_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0296_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_10.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_11.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_19.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_23.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_24.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_25.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_26.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_27.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_28.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_29.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_3.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_30.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_31.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_32.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_33.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_34.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_35.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_36.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_37.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_38.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_4.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_5.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_6.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_7.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_8.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0297_9.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_10.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_11.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_19.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_23.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_24.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_7.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_8.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0298_9.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_10.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_11.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_12.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_13.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_14.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_15.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_16.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_17.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_18.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_24.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_26.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_27.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_28.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_29.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_30.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0299_9.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0300_20.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0300_21.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0300_22.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0300_30.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0300_31.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\16_Morozov_study_0300_32.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-89%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-89%1.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.11.20022053-p12-67%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.13.20022673-p13-77%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.13.20022673-p13-77%2.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.19.20025023-p20-93%3.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.22.20024927-p19-68%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.22.20024927-p19-68%1.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.22.20024927-p19-68%2.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.22.20024927-p20-70%2.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.22.20024927-p20-70%3.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.25.20021568-p23-108%4.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.25.20021568-p23-108%5.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.25.20021568-p24-111%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.25.20021568-p24-111%2.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.25.20027763-p15-53%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.25.20027763-p15-53%1.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.26.20027938-p6-80_1%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.26.20027938-p6-80_1%1.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.26.20027938-p6-80_2%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.26.20027938-p6-80_2%1.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.26.20027938-p6-80_3%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.26.20027938-p6-80_3%1.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.02.28.20029025-p23-182.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.03.01.20029769-p21-73_1%2.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.03.01.20029769-p21-73_2%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.03.03.20030353-p17-106%0.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.03.03.20030353-p17-106%1.png
# Current_image: datasets\ct_scan_3\val\COVID-positive\17_Zhao_2020.03.03.20030775-p11-91.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-09ba87cd6c0f> in <module>
#       1 src_folder_path = "datasets\\ct_scan_3\\val\\COVID-positive\\"
#       2 des_folder_path = "datasets\\ct_scan_7\\val_contrast\\COVID-positive\\"
# ----> 3 mf.aply_black_tophat_to_folder(src_folder_path, des_folder_path, disk_size=12)
#
# c:\Users\arthur.morais\Desktop\code_projects\grad_cam_code\my_functions.py in aply_black_tophat_to_folder(original_folder_path, destination_folder_path, disk_size)
#     263       image_name = current_image_path.split('\\')[-1]
#     264       print("Current_image: {}".format(current_image_path))
# --> 265       result_image = aply_black_tophat_to_image(original_image_path=current_image_path, disk_size=disk_size)
#     266       tf.keras.utils.save_img(
#     267          path="{}seg_version_{}".format(destination_folder_path, image_name),
#
# c:\Users\arthur.morais\Desktop\code_projects\grad_cam_code\my_functions.py in aply_black_tophat_to_image(original_image_path, disk_size)
#     254    normalize_slice = np.true_divide(sample_slice, [255.0], out=None)
#     255    footprint = disk(disk_size)
# --> 256    w_tophat = black_tophat(normalize_slice, footprint)
#     257    w_tophat = np.uint8(255 * w_tophat)
#     258    return w_tophat[:, :, np.newaxis]
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\misc.py in func_out(image, selem, *args, **kwargs)
#      37         if selem is None:
#      38             selem = _default_selem(image.ndim)
# ---> 39         return func(image, selem=selem, *args, **kwargs)
#      40
#      41     return func_out
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\grey.py in black_tophat(image, selem, out)
#     482     else:
#     483         original = image
# --> 484     out = closing(image, selem, out=out)
#     485     if np.issubdtype(out.dtype, np.bool_):
#     486         np.logical_xor(out, original, out=out)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\misc.py in func_out(image, selem, *args, **kwargs)
#      37         if selem is None:
#      38             selem = _default_selem(image.ndim)
# ---> 39         return func(image, selem=selem, *args, **kwargs)
#      40
#      41     return func_out
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\grey.py in func_out(image, selem, out, *args, **kwargs)
#     120         else:
#     121             out_temp = out
# --> 122         out_temp = func(image, selem, out=out_temp, *args, **kwargs)
#     123         if padding:
#     124             out[:] = crop(out_temp, pad_widths)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\grey.py in closing(image, selem, out)
#     349     dilated = dilation(image, selem)
#     350     # note: shift_x, shift_y do nothing if selem side length is odd
# --> 351     out = erosion(dilated, selem, out=out, shift_x=True, shift_y=True)
#     352     return out
#     353
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\misc.py in func_out(image, selem, *args, **kwargs)
#      37         if selem is None:
#      38             selem = _default_selem(image.ndim)
# ---> 39         return func(image, selem=selem, *args, **kwargs)
#      40
#      41     return func_out
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\skimage\morphology\grey.py in erosion(image, selem, out, shift_x, shift_y)
#     183     if out is None:
#     184         out = np.empty_like(image)
# --> 185     ndi.grey_erosion(image, footprint=selem, output=out)
#     186     return out
#     187
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\ndimage\morphology.py in grey_erosion(input, size, footprint, structure, output, mode, cval, origin)
#    1220
#    1221     return filters._min_or_max_filter(input, size, footprint, structure,
# -> 1222                                       output, mode, cval, origin, 1)
#    1223
#    1224
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\ndimage\filters.py in _min_or_max_filter(input, size, footprint, structure, output, mode, cval, origin, minimum)
#    1150         mode = _ni_support._extend_mode_to_code(mode)
#    1151         _nd_image.min_or_max_filter(input, footprint, structure, output,
# -> 1152                                     mode, cval, origins, minimum)
#    1153     if temp_needed:
#    1154         temp[...] = output
#
# KeyboardInterrupt:
